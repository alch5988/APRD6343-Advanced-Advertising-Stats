# %% [markdown]
# # Time Series Analysis Project
# ### Part 6: Assess whether advertising expenditures "granger cause" or predict search interest data
# ### Written By Ali Chen

# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LassoLarsCV
import matplotlib.pyplot as pyplot
import warnings
from sklearn.metrics import mean_squared_error
warnings.filterwarnings('ignore')

# %%
#Import differenced/lagged data from CSV
alldata = pd.read_csv("google_adspend_differenced_lagged_fordatarobot.csv")

# %%
#Set index parameters as "fixed time"
alldata.set_index(alldata['FIXED TIME'], inplace=True)

# %%
#View list of columns from alldata
list(alldata)
# Out:
# ['FIXED TIME',
#  'CABLE TV_diff',
#  'CABLE TV_diff_lag1',
#  'CABLE TV_diff_lag2',
#  'CABLE TV_diff_lag3',
#  'CABLE TV_diff_lag4',
#  'CABLE TV_diff_lag5',
#  'CABLE TV_diff_lag6',
#  'CABLE TV_diff_lag7',
#  'CABLE TV_diff_lag8',
#  'MAGAZINES_diff',
#  'MAGAZINES_diff_lag1',
#  'MAGAZINES_diff_lag2',
#  'MAGAZINES_diff_lag3',
#  'MAGAZINES_diff_lag4',
#  'MAGAZINES_diff_lag5',
#  'MAGAZINES_diff_lag6',
#  'MAGAZINES_diff_lag7',
#  'MAGAZINES_diff_lag8',
#  'NAT SPOT RADIO_diff',
#  'NAT SPOT RADIO_diff_lag1',
#  'NAT SPOT RADIO_diff_lag2',
#  'NAT SPOT RADIO_diff_lag3',
#  'NAT SPOT RADIO_diff_lag4',
#  'NAT SPOT RADIO_diff_lag5',
#  'NAT SPOT RADIO_diff_lag6',
#  'NAT SPOT RADIO_diff_lag7',
#  'NAT SPOT RADIO_diff_lag8',
#  'NATL NEWSP_diff',
#  'NATL NEWSP_diff_lag1',
#  'NATL NEWSP_diff_lag2',
#  'NATL NEWSP_diff_lag3',
#  'NATL NEWSP_diff_lag4',
#  'NATL NEWSP_diff_lag5',
#  'NATL NEWSP_diff_lag6',
#  'NATL NEWSP_diff_lag7',
#  'NATL NEWSP_diff_lag8',
#  'NETWORK RADIO_diff',
#  'NETWORK RADIO_diff_lag1',
#  'NETWORK RADIO_diff_lag2',
#  'NETWORK RADIO_diff_lag3',
#  'NETWORK RADIO_diff_lag4',
#  'NETWORK RADIO_diff_lag5',
#  'NETWORK RADIO_diff_lag6',
#  'NETWORK RADIO_diff_lag7',
#  'NETWORK RADIO_diff_lag8',
#  'NETWORK TV_diff',
#  'NETWORK TV_diff_lag1',
#  'NETWORK TV_diff_lag2',
#  'NETWORK TV_diff_lag3',
#  'NETWORK TV_diff_lag4',
#  'NETWORK TV_diff_lag5',
#  'NETWORK TV_diff_lag6',
#  'NETWORK TV_diff_lag7',
#  'NETWORK TV_diff_lag8',
#  'NEWSPAPER_diff',
#  'NEWSPAPER_diff_lag1',
#  'NEWSPAPER_diff_lag2',
#  'NEWSPAPER_diff_lag3',
#  'NEWSPAPER_diff_lag4',
#  'NEWSPAPER_diff_lag5',
#  'NEWSPAPER_diff_lag6',
#  'NEWSPAPER_diff_lag7',
#  'NEWSPAPER_diff_lag8',
#  'OUTDOOR_diff',
#  'OUTDOOR_diff_lag1',
#  'OUTDOOR_diff_lag2',
#  'OUTDOOR_diff_lag3',
#  'OUTDOOR_diff_lag4',
#  'OUTDOOR_diff_lag5',
#  'OUTDOOR_diff_lag6',
#  'OUTDOOR_diff_lag7',
#  'OUTDOOR_diff_lag8',
#  'SPOT TV_diff',
#  'SPOT TV_diff_lag1',
#  'SPOT TV_diff_lag2',
#  'SPOT TV_diff_lag3',
#  'SPOT TV_diff_lag4',
#  'SPOT TV_diff_lag5',
#  'SPOT TV_diff_lag6',
#  'SPOT TV_diff_lag7',
#  'SPOT TV_diff_lag8',
#  'SYNDICATION_diff',
#  'SYNDICATION_diff_lag1',
#  'SYNDICATION_diff_lag2',
#  'SYNDICATION_diff_lag3',
#  'SYNDICATION_diff_lag4',
#  'SYNDICATION_diff_lag5',
#  'SYNDICATION_diff_lag6',
#  'SYNDICATION_diff_lag7',
#  'SYNDICATION_diff_lag8',
#  'TOTAL_diff',
#  'TOTAL_diff_lag1',
#  'TOTAL_diff_lag2',
#  'TOTAL_diff_lag3',
#  'TOTAL_diff_lag4',
#  'TOTAL_diff_lag5',
#  'TOTAL_diff_lag6',
#  'TOTAL_diff_lag7',
#  'TOTAL_diff_lag8',
#  'value_diff']

# %% [markdown]
# ### Remove NAN Values

# %%
#Remove "fixed time" column from dataframe
alldata = alldata.drop(columns=['FIXED TIME'])

#View first 15 rows of dataframe to look for any NAN values
alldata.head(15)
# Out:
#             CABLE TV_diff  CABLE TV_diff_lag1  CABLE TV_diff_lag2  \
# FIXED TIME
# 2013-10-07            NaN                 NaN                 NaN
# 2013-10-14          -38.7                 NaN                 NaN
# 2013-10-21           44.7               -38.7                 NaN
# 2013-10-28           30.8                44.7               -38.7
# 2013-11-04            1.7                30.8                44.7
# 2013-11-11          155.7                 1.7                30.8
# 2013-11-18          106.1               155.7                 1.7
# 2013-11-25           62.4               106.1               155.7
# 2013-12-02          -62.2                62.4               106.1
# 2013-12-09         -343.0               -62.2                62.4
# 2013-12-16            4.4              -343.0               -62.2
# 2013-12-23          620.6                 4.4              -343.0
# 2013-12-30          103.5               620.6                 4.4
# 2014-01-06         -606.0               103.5               620.6
# 2014-01-13          -18.0              -606.0               103.5
#
#             CABLE TV_diff_lag3  CABLE TV_diff_lag4  CABLE TV_diff_lag5  \
# FIXED TIME
# 2013-10-07                 NaN                 NaN                 NaN
# 2013-10-14                 NaN                 NaN                 NaN
# 2013-10-21                 NaN                 NaN                 NaN
# 2013-10-28                 NaN                 NaN                 NaN
# 2013-11-04               -38.7                 NaN                 NaN
# 2013-11-11                44.7               -38.7                 NaN
# 2013-11-18                30.8                44.7               -38.7
# 2013-11-25                 1.7                30.8                44.7
# 2013-12-02               155.7                 1.7                30.8
# 2013-12-09               106.1               155.7                 1.7
# 2013-12-16                62.4               106.1               155.7
# 2013-12-23               -62.2                62.4               106.1
# 2013-12-30              -343.0               -62.2                62.4
# 2014-01-06                 4.4              -343.0               -62.2
# 2014-01-13               620.6                 4.4              -343.0
#
#             CABLE TV_diff_lag6  CABLE TV_diff_lag7  CABLE TV_diff_lag8  \
# FIXED TIME
# 2013-10-07                 NaN                 NaN                 NaN
# 2013-10-14                 NaN                 NaN                 NaN
# 2013-10-21                 NaN                 NaN                 NaN
# 2013-10-28                 NaN                 NaN                 NaN
# 2013-11-04                 NaN                 NaN                 NaN
# 2013-11-11                 NaN                 NaN                 NaN
# 2013-11-18                 NaN                 NaN                 NaN
# 2013-11-25               -38.7                 NaN                 NaN
# 2013-12-02                44.7               -38.7                 NaN
# 2013-12-09                30.8                44.7               -38.7
# 2013-12-16                 1.7                30.8                44.7
# 2013-12-23               155.7                 1.7                30.8
# 2013-12-30               106.1               155.7                 1.7
# 2014-01-06                62.4               106.1               155.7
# 2014-01-13               -62.2                62.4               106.1
#
#             MAGAZINES_diff  ...  TOTAL_diff  TOTAL_diff_lag1  TOTAL_diff_lag2  \
# FIXED TIME                  ...
# 2013-10-07             NaN  ...         NaN              NaN              NaN
# 2013-10-14             0.0  ...      -195.4              NaN              NaN
# 2013-10-21             0.0  ...        48.5           -195.4              NaN
# 2013-10-28             0.0  ...       385.7             48.5           -195.4
# 2013-11-04             0.0  ...       -16.0            385.7             48.5
# 2013-11-11             0.0  ...      -122.7            -16.0            385.7
# 2013-11-18             0.0  ...      1073.9           -122.7            -16.0
# 2013-11-25             0.0  ...       579.6           1073.9           -122.7
# 2013-12-02             0.0  ...     -1054.6            579.6           1073.9
# 2013-12-09             0.0  ...       158.2          -1054.6            579.6
# 2013-12-16             0.0  ...      -824.9            158.2          -1054.6
# 2013-12-23             0.0  ...       917.1           -824.9            158.2
# 2013-12-30             0.0  ...       505.4            917.1           -824.9
# 2014-01-06             0.0  ...     -1678.7            505.4            917.1
# 2014-01-13             0.0  ...       -79.4          -1678.7            505.4
#
#             TOTAL_diff_lag3  TOTAL_diff_lag4  TOTAL_diff_lag5  \
# FIXED TIME
# 2013-10-07              NaN              NaN              NaN
# 2013-10-14              NaN              NaN              NaN
# 2013-10-21              NaN              NaN              NaN
# 2013-10-28              NaN              NaN              NaN
# 2013-11-04           -195.4              NaN              NaN
# 2013-11-11             48.5           -195.4              NaN
# 2013-11-18            385.7             48.5           -195.4
# 2013-11-25            -16.0            385.7             48.5
# 2013-12-02           -122.7            -16.0            385.7
# 2013-12-09           1073.9           -122.7            -16.0
# 2013-12-16            579.6           1073.9           -122.7
# 2013-12-23          -1054.6            579.6           1073.9
# 2013-12-30            158.2          -1054.6            579.6
# 2014-01-06           -824.9            158.2          -1054.6
# 2014-01-13            917.1           -824.9            158.2
#
#             TOTAL_diff_lag6  TOTAL_diff_lag7  TOTAL_diff_lag8   value_diff
# FIXED TIME
# 2013-10-07              NaN              NaN              NaN          NaN
# 2013-10-14              NaN              NaN              NaN -1601.560799
# 2013-10-21              NaN              NaN              NaN    27.615247
# 2013-10-28              NaN              NaN              NaN   600.678190
# 2013-11-04              NaN              NaN              NaN   142.718735
# 2013-11-11              NaN              NaN              NaN   229.787503
# 2013-11-18              NaN              NaN              NaN  -609.065631
# 2013-11-25           -195.4              NaN              NaN  1694.454530
# 2013-12-02             48.5           -195.4              NaN -2456.049152
# 2013-12-09            385.7             48.5           -195.4   596.901842
# 2013-12-16            -16.0            385.7             48.5 -1025.948606
# 2013-12-23           -122.7            -16.0            385.7  2089.646593
# 2013-12-30           1073.9           -122.7            -16.0 -2323.893155
# 2014-01-06            579.6           1073.9           -122.7  1717.594560
# 2014-01-13          -1054.6            579.6           1073.9  -762.555698
#
# [15 rows x 100 columns]

# %%
#Delete first 9 rows to remove NAN values
alldata = alldata.iloc[9:]

alldata.head()
# Out:
#             CABLE TV_diff  CABLE TV_diff_lag1  CABLE TV_diff_lag2  \
# FIXED TIME
# 2013-12-09         -343.0               -62.2                62.4
# 2013-12-16            4.4              -343.0               -62.2
# 2013-12-23          620.6                 4.4              -343.0
# 2013-12-30          103.5               620.6                 4.4
# 2014-01-06         -606.0               103.5               620.6
#
#             CABLE TV_diff_lag3  CABLE TV_diff_lag4  CABLE TV_diff_lag5  \
# FIXED TIME
# 2013-12-09               106.1               155.7                 1.7
# 2013-12-16                62.4               106.1               155.7
# 2013-12-23               -62.2                62.4               106.1
# 2013-12-30              -343.0               -62.2                62.4
# 2014-01-06                 4.4              -343.0               -62.2
#
#             CABLE TV_diff_lag6  CABLE TV_diff_lag7  CABLE TV_diff_lag8  \
# FIXED TIME
# 2013-12-09                30.8                44.7               -38.7
# 2013-12-16                 1.7                30.8                44.7
# 2013-12-23               155.7                 1.7                30.8
# 2013-12-30               106.1               155.7                 1.7
# 2014-01-06                62.4               106.1               155.7
#
#             MAGAZINES_diff  ...  TOTAL_diff  TOTAL_diff_lag1  TOTAL_diff_lag2  \
# FIXED TIME                  ...
# 2013-12-09             0.0  ...       158.2          -1054.6            579.6
# 2013-12-16             0.0  ...      -824.9            158.2          -1054.6
# 2013-12-23             0.0  ...       917.1           -824.9            158.2
# 2013-12-30             0.0  ...       505.4            917.1           -824.9
# 2014-01-06             0.0  ...     -1678.7            505.4            917.1
#
#             TOTAL_diff_lag3  TOTAL_diff_lag4  TOTAL_diff_lag5  \
# FIXED TIME
# 2013-12-09           1073.9           -122.7            -16.0
# 2013-12-16            579.6           1073.9           -122.7
# 2013-12-23          -1054.6            579.6           1073.9
# 2013-12-30            158.2          -1054.6            579.6
# 2014-01-06           -824.9            158.2          -1054.6
#
#             TOTAL_diff_lag6  TOTAL_diff_lag7  TOTAL_diff_lag8   value_diff
# FIXED TIME
# 2013-12-09            385.7             48.5           -195.4   596.901842
# 2013-12-16            -16.0            385.7             48.5 -1025.948606
# 2013-12-23           -122.7            -16.0            385.7  2089.646593
# 2013-12-30           1073.9           -122.7            -16.0 -2323.893155
# 2014-01-06            579.6           1073.9           -122.7  1717.594560
#
# [5 rows x 100 columns]

# %%
#View tail of dataframe to check for NAN values
alldata.tail(15)
# Out:
#             CABLE TV_diff  CABLE TV_diff_lag1  CABLE TV_diff_lag2  \
# FIXED TIME
# 2018-08-20            0.0                 0.0                 0.0
# 2018-08-27            0.0                 0.0                 0.0
# 2018-09-03            0.0                 0.0                 0.0
# 2018-09-10           23.0                 0.0                 0.0
# 2018-09-17          587.4                23.0                 0.0
# 2018-09-24          104.3               587.4                23.0
# 2018-10-01           78.8               104.3               587.4
# 2018-10-08            NaN                78.8               104.3
# 2018-10-15            NaN                 NaN                78.8
# 2018-10-22            NaN                 NaN                 NaN
# 2018-10-29            NaN                 NaN                 NaN
# 2018-11-05            NaN                 NaN                 NaN
# 2018-11-12            NaN                 NaN                 NaN
# 2018-11-19            NaN                 NaN                 NaN
# 2018-11-26            NaN                 NaN                 NaN
#
#             CABLE TV_diff_lag3  CABLE TV_diff_lag4  CABLE TV_diff_lag5  \
# FIXED TIME
# 2018-08-20                 0.0                 0.0                 0.0
# 2018-08-27                 0.0                 0.0                 0.0
# 2018-09-03                 0.0                 0.0                 0.0
# 2018-09-10                 0.0                 0.0                 0.0
# 2018-09-17                 0.0                 0.0                 0.0
# 2018-09-24                 0.0                 0.0                 0.0
# 2018-10-01                23.0                 0.0                 0.0
# 2018-10-08               587.4                23.0                 0.0
# 2018-10-15               104.3               587.4                23.0
# 2018-10-22                78.8               104.3               587.4
# 2018-10-29                 NaN                78.8               104.3
# 2018-11-05                 NaN                 NaN                78.8
# 2018-11-12                 NaN                 NaN                 NaN
# 2018-11-19                 NaN                 NaN                 NaN
# 2018-11-26                 NaN                 NaN                 NaN
#
#             CABLE TV_diff_lag6  CABLE TV_diff_lag7  CABLE TV_diff_lag8  \
# FIXED TIME
# 2018-08-20                 0.0                 0.0                -9.0
# 2018-08-27                 0.0                 0.0                 0.0
# 2018-09-03                 0.0                 0.0                 0.0
# 2018-09-10                 0.0                 0.0                 0.0
# 2018-09-17                 0.0                 0.0                 0.0
# 2018-09-24                 0.0                 0.0                 0.0
# 2018-10-01                 0.0                 0.0                 0.0
# 2018-10-08                 0.0                 0.0                 0.0
# 2018-10-15                 0.0                 0.0                 0.0
# 2018-10-22                23.0                 0.0                 0.0
# 2018-10-29               587.4                23.0                 0.0
# 2018-11-05               104.3               587.4                23.0
# 2018-11-12                78.8               104.3               587.4
# 2018-11-19                 NaN                78.8               104.3
# 2018-11-26                 NaN                 NaN                78.8
#
#             MAGAZINES_diff  ...  TOTAL_diff  TOTAL_diff_lag1  TOTAL_diff_lag2  \
# FIXED TIME                  ...
# 2018-08-20             0.0  ...         0.0              0.0           -319.9
# 2018-08-27             0.0  ...       660.1              0.0              0.0
# 2018-09-03             0.0  ...      -165.1            660.1              0.0
# 2018-09-10             0.0  ...        65.0           -165.1            660.1
# 2018-09-17             0.0  ...      4775.6             65.0           -165.1
# 2018-09-24             0.0  ...       717.0           4775.6             65.0
# 2018-10-01             0.0  ...     -2141.7            717.0           4775.6
# 2018-10-08             NaN  ...         NaN          -2141.7            717.0
# 2018-10-15             NaN  ...         NaN              NaN          -2141.7
# 2018-10-22             NaN  ...         NaN              NaN              NaN
# 2018-10-29             NaN  ...         NaN              NaN              NaN
# 2018-11-05             NaN  ...         NaN              NaN              NaN
# 2018-11-12             NaN  ...         NaN              NaN              NaN
# 2018-11-19             NaN  ...         NaN              NaN              NaN
# 2018-11-26             NaN  ...         NaN              NaN              NaN
#
#             TOTAL_diff_lag3  TOTAL_diff_lag4  TOTAL_diff_lag5  \
# FIXED TIME
# 2018-08-20            328.3              1.5              5.0
# 2018-08-27           -319.9            328.3              1.5
# 2018-09-03              0.0           -319.9            328.3
# 2018-09-10              0.0              0.0           -319.9
# 2018-09-17            660.1              0.0              0.0
# 2018-09-24           -165.1            660.1              0.0
# 2018-10-01             65.0           -165.1            660.1
# 2018-10-08           4775.6             65.0           -165.1
# 2018-10-15            717.0           4775.6             65.0
# 2018-10-22          -2141.7            717.0           4775.6
# 2018-10-29              NaN          -2141.7            717.0
# 2018-11-05              NaN              NaN          -2141.7
# 2018-11-12              NaN              NaN              NaN
# 2018-11-19              NaN              NaN              NaN
# 2018-11-26              NaN              NaN              NaN
#
#             TOTAL_diff_lag6  TOTAL_diff_lag7  TOTAL_diff_lag8   value_diff
# FIXED TIME
# 2018-08-20              0.0           -309.8            382.8  2163.899921
# 2018-08-27              5.0              0.0           -309.8  -803.102166
# 2018-09-03              1.5              5.0              0.0   542.626875
# 2018-09-10            328.3              1.5              5.0 -1285.732804
# 2018-09-17           -319.9            328.3              1.5  1059.457829
# 2018-09-24              0.0           -319.9            328.3  2655.251636
# 2018-10-01              0.0              0.0           -319.9 -4135.399471
# 2018-10-08            660.1              0.0              0.0          NaN
# 2018-10-15           -165.1            660.1              0.0          NaN
# 2018-10-22             65.0           -165.1            660.1          NaN
# 2018-10-29           4775.6             65.0           -165.1          NaN
# 2018-11-05            717.0           4775.6             65.0          NaN
# 2018-11-12          -2141.7            717.0           4775.6          NaN
# 2018-11-19              NaN          -2141.7            717.0          NaN
# 2018-11-26              NaN              NaN          -2141.7          NaN
#
# [15 rows x 100 columns]

# %%
#Delete last 8 rows from dataframe to remove NAN values
alldata = alldata.iloc[:-8]

alldata.tail()
# Out:
#             CABLE TV_diff  CABLE TV_diff_lag1  CABLE TV_diff_lag2  \
# FIXED TIME
# 2018-09-03            0.0                 0.0                 0.0
# 2018-09-10           23.0                 0.0                 0.0
# 2018-09-17          587.4                23.0                 0.0
# 2018-09-24          104.3               587.4                23.0
# 2018-10-01           78.8               104.3               587.4
#
#             CABLE TV_diff_lag3  CABLE TV_diff_lag4  CABLE TV_diff_lag5  \
# FIXED TIME
# 2018-09-03                 0.0                 0.0                 0.0
# 2018-09-10                 0.0                 0.0                 0.0
# 2018-09-17                 0.0                 0.0                 0.0
# 2018-09-24                 0.0                 0.0                 0.0
# 2018-10-01                23.0                 0.0                 0.0
#
#             CABLE TV_diff_lag6  CABLE TV_diff_lag7  CABLE TV_diff_lag8  \
# FIXED TIME
# 2018-09-03                 0.0                 0.0                 0.0
# 2018-09-10                 0.0                 0.0                 0.0
# 2018-09-17                 0.0                 0.0                 0.0
# 2018-09-24                 0.0                 0.0                 0.0
# 2018-10-01                 0.0                 0.0                 0.0
#
#             MAGAZINES_diff  ...  TOTAL_diff  TOTAL_diff_lag1  TOTAL_diff_lag2  \
# FIXED TIME                  ...
# 2018-09-03             0.0  ...      -165.1            660.1              0.0
# 2018-09-10             0.0  ...        65.0           -165.1            660.1
# 2018-09-17             0.0  ...      4775.6             65.0           -165.1
# 2018-09-24             0.0  ...       717.0           4775.6             65.0
# 2018-10-01             0.0  ...     -2141.7            717.0           4775.6
#
#             TOTAL_diff_lag3  TOTAL_diff_lag4  TOTAL_diff_lag5  \
# FIXED TIME
# 2018-09-03              0.0           -319.9            328.3
# 2018-09-10              0.0              0.0           -319.9
# 2018-09-17            660.1              0.0              0.0
# 2018-09-24           -165.1            660.1              0.0
# 2018-10-01             65.0           -165.1            660.1
#
#             TOTAL_diff_lag6  TOTAL_diff_lag7  TOTAL_diff_lag8   value_diff
# FIXED TIME
# 2018-09-03              1.5              5.0              0.0   542.626875
# 2018-09-10            328.3              1.5              5.0 -1285.732804
# 2018-09-17           -319.9            328.3              1.5  1059.457829
# 2018-09-24              0.0           -319.9            328.3  2655.251636
# 2018-10-01              0.0              0.0           -319.9 -4135.399471
#
# [5 rows x 100 columns]

# %% [markdown]
# ### Initiate Predictor Variables

# %%
#Initiate variable for list of predictors
listofallpredictors = []

# %%
#For loop to iterate through data to extract predictor variables into list
for avar in list(alldata):
    if "value" not in avar:
        listofallpredictors.append(avar)

# %%
#View list of all predictor columns
print(listofallpredictors)
# Out:
# ['CABLE TV_diff', 'CABLE TV_diff_lag1', 'CABLE TV_diff_lag2', 'CABLE TV_diff_lag3', 'CABLE TV_diff_lag4', 'CABLE TV_diff_lag5', 'CABLE TV_diff_lag6', 'CABLE TV_diff_lag7', 'CABLE TV_diff_lag8', 'MAGAZINES_diff', 'MAGAZINES_diff_lag1', 'MAGAZINES_diff_lag2', 'MAGAZINES_diff_lag3', 'MAGAZINES_diff_lag4', 'MAGAZINES_diff_lag5', 'MAGAZINES_diff_lag6', 'MAGAZINES_diff_lag7', 'MAGAZINES_diff_lag8', 'NAT SPOT RADIO_diff', 'NAT SPOT RADIO_diff_lag1', 'NAT SPOT RADIO_diff_lag2', 'NAT SPOT RADIO_diff_lag3', 'NAT SPOT RADIO_diff_lag4', 'NAT SPOT RADIO_diff_lag5', 'NAT SPOT RADIO_diff_lag6', 'NAT SPOT RADIO_diff_lag7', 'NAT SPOT RADIO_diff_lag8', 'NATL NEWSP_diff', 'NATL NEWSP_diff_lag1', 'NATL NEWSP_diff_lag2', 'NATL NEWSP_diff_lag3', 'NATL NEWSP_diff_lag4', 'NATL NEWSP_diff_lag5', 'NATL NEWSP_diff_lag6', 'NATL NEWSP_diff_lag7', 'NATL NEWSP_diff_lag8', 'NETWORK RADIO_diff', 'NETWORK RADIO_diff_lag1', 'NETWORK RADIO_diff_lag2', 'NETWORK RADIO_diff_lag3', 'NETWORK RADIO_diff_lag4', 'NETWORK RADIO_diff_lag5', 'NETWORK RADIO_diff_lag6', 'NETWORK RADIO_diff_lag7', 'NETWORK RADIO_diff_lag8', 'NETWORK TV_diff', 'NETWORK TV_diff_lag1', 'NETWORK TV_diff_lag2', 'NETWORK TV_diff_lag3', 'NETWORK TV_diff_lag4', 'NETWORK TV_diff_lag5', 'NETWORK TV_diff_lag6', 'NETWORK TV_diff_lag7', 'NETWORK TV_diff_lag8', 'NEWSPAPER_diff', 'NEWSPAPER_diff_lag1', 'NEWSPAPER_diff_lag2', 'NEWSPAPER_diff_lag3', 'NEWSPAPER_diff_lag4', 'NEWSPAPER_diff_lag5', 'NEWSPAPER_diff_lag6', 'NEWSPAPER_diff_lag7', 'NEWSPAPER_diff_lag8', 'OUTDOOR_diff', 'OUTDOOR_diff_lag1', 'OUTDOOR_diff_lag2', 'OUTDOOR_diff_lag3', 'OUTDOOR_diff_lag4', 'OUTDOOR_diff_lag5', 'OUTDOOR_diff_lag6', 'OUTDOOR_diff_lag7', 'OUTDOOR_diff_lag8', 'SPOT TV_diff', 'SPOT TV_diff_lag1', 'SPOT TV_diff_lag2', 'SPOT TV_diff_lag3', 'SPOT TV_diff_lag4', 'SPOT TV_diff_lag5', 'SPOT TV_diff_lag6', 'SPOT TV_diff_lag7', 'SPOT TV_diff_lag8', 'SYNDICATION_diff', 'SYNDICATION_diff_lag1', 'SYNDICATION_diff_lag2', 'SYNDICATION_diff_lag3', 'SYNDICATION_diff_lag4', 'SYNDICATION_diff_lag5', 'SYNDICATION_diff_lag6', 'SYNDICATION_diff_lag7', 'SYNDICATION_diff_lag8', 'TOTAL_diff', 'TOTAL_diff_lag1', 'TOTAL_diff_lag2', 'TOTAL_diff_lag3', 'TOTAL_diff_lag4', 'TOTAL_diff_lag5', 'TOTAL_diff_lag6', 'TOTAL_diff_lag7', 'TOTAL_diff_lag8']

# %%
#Set the list of all predictors to a variable for "predictors"
predictors = alldata[listofallpredictors]

# %%
#Set target variable as "value_diff" 
target = alldata['value_diff']

# %%
#Split data into training and test sets
pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size = 0.3, random_state=123)

# %% [markdown]
# ### Initiate LassoLars Model

# %%
#Model = LassoLarsCV
model = LassoLarsCV(cv=10, precompute=False)

# %%
#Use fit function to fit training set to model
model = model.fit(pred_train.values, tar_train.values)

# %%
#Specify model output
predictors_model = pd.DataFrame(listofallpredictors)
predictors_model.columns = ['label']
predictors_model['coeff'] = model.coef_

# %%
#For loop to iterate through dataframe to print any coefficient with significance (value greater than zero)
for index, row in predictors_model.iterrows():
    if row['coeff'] > 0:
        print(row.values)
# Out:
# ['OUTDOOR_diff_lag8' 0.12580664564473834]

# %%
#Calculate error on training set
train_error = mean_squared_error(tar_train, model.predict(pred_train))
print('training data MSE')
print(train_error)

#training data MSE = 556705.7715479546
# Out:
# training data MSE
# 577773.3368524646

# %%
#Calculate error on test set
test_error = mean_squared_error(tar_test, model.predict(pred_test))
print('testing data MSE')
print(test_error)

#testing data MSE = 393276.69259595184
# Out:
# testing data MSE
# 335253.436490225

# %%
#Calculate R squared on training set
rsquared_train=model.score(pred_train,tar_train)
print ('training data R-square')
print(rsquared_train)

#training data R-square = 0.06469596590025772
# Out:
# training data R-square
# 0.022136944739665765

# %%
#Calculate R squared on test set
rsquared_test=model.score(pred_test,tar_test)
print ('testing data R-square')
print(rsquared_test)

#testing data R-square = -0.029811451023880498
# Out:
# testing data R-square
# -0.016076679916917858
